# %%
from serenata_toolbox.datasets import Datasets
import pandas as pd

# %%
pd.read_csv('/tmp/serenata-data/Ano-2018.csv', sep = ';')
# Out:
#        txNomeParlamentar           cpf  ideCadastro  nuCarteiraParlamentar  \
# 0                 AVANTE           NaN          NaN                    NaN
# 1                 AVANTE           NaN          NaN                    NaN
# 2                 AVANTE           NaN          NaN                    NaN
# 3                 AVANTE           NaN          NaN                    NaN
# 4                 AVANTE           NaN          NaN                    NaN
# ...                  ...           ...          ...                    ...
# 292479      FELIPE SOUZA  3.848737e+10     205234.0                  620.0
# 292480      FELIPE SOUZA  3.848737e+10     205234.0                  620.0
# 292481      FELIPE SOUZA  3.848737e+10     205234.0                  620.0
# 292482      FELIPE SOUZA  3.848737e+10     205234.0                  620.0
# 292483      FELIPE SOUZA  3.848737e+10     205234.0                  620.0
#
#         nuLegislatura sgUF sgPartido  codLegislatura  numSubCota  \
# ...
